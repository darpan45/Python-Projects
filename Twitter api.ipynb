# %%
import tweepy
from wordcloud import WordCloud,STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt
% matplotlib inline

# %%
consumer_key="I1TZwNJ6t8qCfkNnXcEoVaLeG"
consumer_secret="o4CZj6CasEDwM3GLplf0kDffomhPQxM3bTIgJsPOzcDjdGYOTB"
access_token="1071756255889223681-gfmEsNe7IqxM8EAUAm8BAl4GECxeql"
access_token_secret="eu2w6HVKC7UlVJVVJ1yeGoQZZ9DiisaLUYnyEqNjXoqcf"

# %%
# Creating the authentication object
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
# Setting your access token and secret
auth.set_access_token(access_token, access_token_secret)
# Creating the API object while passing in auth information
api = tweepy.API(auth)

# %%
search_term = "election2019"
number_of_tweets = 5
stopwords = set(STOPWORDS)
stopwords.update(["https", "Tweeted","pls","retweet","issued","well","till","co","RT"])
tweets = tweepy.Cursor(api.search, q=search_term, lang="en").items(number_of_tweets)


cloud = ""
for x in tweets:
    cloud = cloud + x.text
    print(x.user.screen_name,"Tweeted:",x.text)
# Out:
# tweety_sweetie2 Tweeted: RT @sanchitabhartiy: @IMAGE_Eyewear @IMAGEeyeWear With great power comes great responsibility!
# Vote responsibly..
# #election2019 #voteindia…
# dev071427 Tweeted: RT @iKabirBedi: BIGGEST SHOW ON EARTH! #Election2019 is the world's biggest event,
# with 22 languages, 100s of dialects, 1000s of ethnic gr…
# Varunnn__ Tweeted: RT @Meenaxidixit: I voted! did u? #LokSabhaEelctions2019 #Election2019 #MumbaiVotesForNation https://t.co/aMICkSUT65
# abdul_l99 Tweeted: RT @1petermartin: Can you vote for a government where the minister for education suggests that welfare is communism? https://t.co/sjAPJLSiG…
# PoojaSKARtweetz Tweeted: RT @AmritaRao: You Have the Power to Give Power...
# #GoVote Today!
# #Election2019 https://t.co/wa2MPJbT7C

# %%
cloud = WordCloud(stopwords=stopwords,background_color="white").generate(cloud)
plt.imshow(cloud, interpolation='bilinear')
plt.axis("off")
plt.show()
